# %% [markdown]
# EXP 0 : INTRODUCTION TO PYTHON

# %%
# Saumya Shree - 25070123161
print("Saumya Shree")
# Out:
# Saumya Shree

# %%
print(2)
# Out:
# 2

# %%
print([1,2,5])
# Out:
# [1, 2, 5]

# %%
print("Saumya Shree")
print(2)
print([1,2,3])
# Out:
# Saumya Shree
# 2
# [1, 2, 3]

# %%
x = 2
y = [1,2,5]
z = "Saumya Shree"
print(x)
print(y)
print(z)
# Out:
# 2
# [1, 2, 5]
# Saumya Shree

# %%
x = 2
y = [1,2,5]
z = "Saumya Shree"
print(x,y,z)
# Out:
# 2 [1, 2, 5] Saumya Shree

# %%
x = 2
y = [1,2,5]
z ="Saumya Shree"
print(x,y,z,sep="\n")
# Out:
# 2
# [1, 2, 5]
# Saumya Shree
